# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf
import random
from collections import Counter

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
import time

def subsample_words(words, threshold):  
    # This will be the probability to keep each word
    keep_probs = np.random.uniform(0.0, 1.0, len(words))
    
    total_words = len(words)
    
    # Counting the frequency of each word
    words_freqs = Counter(words)
    words_freqs = {word: count/total_words for word, count in words_freqs.items()}
    
    # Placeholder to keep the train words
    keep_words = []
    
    for idx, word in enumerate(words):
        discard_prob = 1.0 - np.sqrt(threshold / words_freqs[word])
        
        if keep_probs[idx] >= discard_prob:
            keep_words.append(word)
            
    return keep_words

# %%
## Your code here
train_words = subsample_words(int_wordswords, threshold=1e-5)

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    
    r = np.random.randint(1, window_size + 1)
    low_idx = max(idx - r, 0)
    high_idx = min(idx + r + 1, len(words) - 1)
    
    wnd = set(words[low_idx:idx] + words[idx+1:high_idx])
    
    return list(wnd)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels=labels,
                                      inputs=embed, num_sampled=n_sampled, num_classes=n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6454 0.0260 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6551 0.0219 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4888 0.0219 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6106 0.0220 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5444 0.0219 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.4912 0.0221 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5386 0.0231 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5544 0.0223 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4772 0.0225 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4555 0.0223 sec/batch
# Nearest to d: organisations, subsidiary, motorised, showtime, capell, dolphin, interrogators, gait,
# Nearest to while: huns, hydrothermal, wastage, also, mode, destroys, supercluster, deploy,
# Nearest to that: agnostic, guatemala, seminole, unfortunately, predetermined, character, wave, geirr,
# Nearest to and: viceroys, shred, weight, laundry, hitchhiking, unicameral, ellis, preaching,
# Nearest to would: setback, determination, satam, compendium, abramson, instead, akhenaten, agra,
# Nearest to if: celsius, toot, workplaces, gottwald, aforementioned, slava, derrida, dilemmas,
# Nearest to when: mathematical, stefano, booking, shiva, interrupt, talker, vibrations, harmful,
# Nearest to his: ld, nitride, consumes, thema, praenomen, mornay, kidnapped, veishea,
# Nearest to defense: hereditary, portraiture, a, provisionally, composite, nodes, burgundians, camelopardalis,
# Nearest to institute: purity, tur, reshaped, noun, spoofing, whaler, used, adjuncts,
# Nearest to channel: villain, fujita, novo, commemorates, sans, subsequent, secretory, felonies,
# Nearest to mathematics: chair, coastlines, doorway, femme, powerboat, hazmi, fallacies, ella,
# Nearest to brother: colt, discourse, rig, lydians, discography, schlesinger, kel, loops,
# Nearest to centre: gong, habsburg, televangelist, bishop, almoravids, resembled, kushan, seabirds,
# Nearest to running: incapable, prepubescent, splendor, bootlegs, greenish, attacking, ranches, asserts,
# Nearest to universe: tempe, declining, rule, apprehend, hobby, riverside, takers, nni,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5078 0.0228 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4301 0.0223 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3389 0.0220 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2515 0.0220 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2166 0.0247 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1591 0.0219 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1045 0.0217 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0638 0.0219 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0441 0.0216 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0081 0.0225 sec/batch
# Nearest to d: organisations, subsidiary, dolphin, union, southern, motorised, colonial, showtime,
# Nearest to while: also, game, mode, constitutional, sharp, work, huns, younger,
# Nearest to that: character, so, wave, guatemala, agnostic, order, markets, unfortunately,
# Nearest to and: viceroys, shred, larger, unicameral, iy, ellis, asserted, weight,
# Nearest to would: instead, determination, compendium, if, setback, reject, abramson, satam,
# Nearest to if: would, celsius, proportions, aforementioned, toot, cup, contrast, orthodoxy,
# Nearest to when: mathematical, interrupt, shiva, harmful, booking, company, tremendously, beginning,
# Nearest to his: ld, encounter, taiwan, kidnapped, contrast, players, consumes, overt,
# Nearest to defense: hereditary, composite, eliminating, later, a, nodes, materials, burgundians,
# Nearest to institute: purity, used, reshaped, tur, noun, spoofing, has, whaler,
# Nearest to channel: villain, on, subsequent, sans, secretory, commemorates, fujita, ch,
# Nearest to mathematics: chair, entitled, ella, broadband, luxuries, vita, femme, richness,
# Nearest to brother: colt, discourse, serious, rig, loops, believed, situations, helmet,
# Nearest to centre: habsburg, gong, progress, presumably, accused, resembled, almoravids, banco,
# Nearest to running: prepubescent, incapable, extensive, attacking, asserts, greenish, ranches, splendor,
# Nearest to universe: tempe, rule, declining, catholicism, designing, riverside, takers, inheritance,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9663 0.0226 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9047 0.0216 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8728 0.0237 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8668 0.0283 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8141 0.0216 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8182 0.0219 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7790 0.0223 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8014 0.0219 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7615 0.0220 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7800 0.0219 sec/batch
# Nearest to d: organisations, subsidiary, dolphin, union, capell, jacinto, motorised, showtime,
# Nearest to while: huns, destroys, also, constitutional, sharp, wastage, younger, controlling,
# Nearest to that: character, agnostic, so, wave, guatemala, order, reciprocal, markets,
# Nearest to and: viceroys, unicameral, shred, ellis, kidnapping, asserted, thigh, campaigner,
# Nearest to would: determination, instead, compendium, reject, setback, if, abramson, akhenaten,
# Nearest to if: celsius, would, toot, proportions, workplaces, resigns, bearings, attacking,
# Nearest to when: mathematical, harmful, booking, interrupt, company, shiva, pacifist, recognizes,
# Nearest to his: ld, kidnapped, statesmen, encounter, taiwan, nineties, thema, appointments,
# Nearest to defense: hereditary, nodes, hudson, composite, eliminating, mta, entscheidungsproblem, provisionally,
# Nearest to institute: purity, reshaped, tur, used, spoofing, noun, identifiable, flourished,
# Nearest to channel: on, villain, subsequent, commemorates, sans, renamed, secretory, ch,
# Nearest to mathematics: chair, ella, femme, entitled, richness, broadband, vita, coastlines,
# Nearest to brother: discourse, colt, rig, loops, discography, surprising, friction, helmet,
# Nearest to centre: habsburg, presumably, progress, gong, resembled, accused, bishop, illustrate,
# Nearest to running: incapable, prepubescent, attacking, asserts, extensive, shadows, greenish, foundation,
# Nearest to universe: tempe, rule, catholicism, declining, hobby, riverside, inheritance, takers,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7912 0.0228 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7319 0.0221 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7296 0.0218 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7284 0.0218 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7432 0.0225 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6813 0.0219 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6987 0.0218 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7162 0.0218 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6914 0.0220 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6575 0.0221 sec/batch
# Nearest to d: jacinto, composer, capell, vandalised, yue, six, mumford, migrant,
# Nearest to while: huns, destroys, constitutional, deploy, younger, wastage, also, controlling,
# Nearest to that: character, agnostic, guatemala, reciprocal, order, so, markets, evidence,
# Nearest to and: viceroys, kidnapping, shred, asserted, unicameral, campaigner, ellis, thigh,
# Nearest to would: setback, compendium, determination, instead, reject, akhenaten, prokaryote, postumus,
# Nearest to if: celsius, dilemmas, toot, workplaces, spina, would, gottwald, bearings,
# Nearest to when: mathematical, booking, harmful, interrupt, shiva, headaches, pacifist, reddy,
# Nearest to his: ld, statesmen, kidnapped, thema, nineties, taiwan, encounter, lacan,
# Nearest to defense: hereditary, hudson, nodes, portraiture, composite, eliminating, burgundians, provisionally,
# Nearest to institute: purity, tur, reshaped, used, spoofing, planing, whaler, identifiable,
# Nearest to channel: on, commemorates, subsequent, villain, sans, novo, renamed, secretory,
# Nearest to mathematics: chair, ella, femme, richness, vita, doorway, fallacies, chemotherapy,
# Nearest to brother: colt, discourse, rig, wojty, qatar, schlesinger, loops, surprising,
# Nearest to centre: habsburg, archbishop, gong, bishop, almoravids, presumably, resembled, sometime,
# Nearest to running: incapable, prepubescent, attacking, asserts, shadows, greenish, extensive, bootlegs,
# Nearest to universe: tempe, apprehend, rule, inheritance, riverside, takers, hobby, catholicism,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6714 0.0223 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6626 0.0216 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6005 0.0217 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6169 0.0219 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6371 0.0216 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6420 0.0217 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6069 0.0160 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5502 0.0216 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4898 0.0221 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5081 0.0221 sec/batch
# Nearest to d: composer, six, actress, jacinto, artist, one, leopold, french,
# Nearest to while: huns, destroys, constitutional, deploy, drifting, sharp, controlling, wastage,
# Nearest to that: character, agnostic, so, evidence, reciprocal, order, guatemala, wave,
# Nearest to and: viceroys, kidnapping, shred, aboriginals, campaigner, thigh, asserted, unicameral,
# Nearest to would: instead, compendium, reject, determination, setback, they, akhenaten, selassie,
# Nearest to if: dilemmas, spina, bearings, would, thin, celsius, illumination, negativity,
# Nearest to when: booking, mathematical, harmful, interrupt, santer, headaches, pacifist, shiva,
# Nearest to his: statesmen, kidnapped, ld, thema, encounter, nineties, mornay, synge,
# Nearest to defense: hereditary, nodes, hudson, portraiture, eliminating, entscheidungsproblem, amended, camelopardalis,
# Nearest to institute: tur, reshaped, purity, spoofing, used, com, planing, adjuncts,
# Nearest to channel: on, commemorates, subsequent, novo, renamed, villain, caucasoid, sans,
# Nearest to mathematics: femme, chair, ella, doorway, joys, richness, vita, chemotherapy,
# Nearest to brother: rig, colt, discourse, wojty, tutelary, evelyn, ibero, regents,
# Nearest to centre: habsburg, bishop, archbishop, gong, almoravids, omnipotent, resembled, kushan,
# Nearest to running: prepubescent, incapable, attacking, greenish, shadows, extensive, rogue, bootlegs,
# Nearest to universe: tempe, apprehend, takers, inheritance, riverside, hobby, theory, bius,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5028 0.0227 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5078 0.0218 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4439 0.0218 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5320 0.0215 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4936 0.0218 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4933 0.0217 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4539 0.0219 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3915 0.0216 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4237 0.0219 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4334 0.0217 sec/batch
# Nearest to d: composer, jacinto, vandalised, aleksandr, artist, capell, yue, collegetown,
# Nearest to while: huns, controlling, destroys, sharp, opioids, broadleaf, constitutional, hydrothermal,
# Nearest to that: character, agnostic, so, order, evidence, reciprocal, wave, scientifique,
# Nearest to and: viceroys, aboriginals, thigh, shred, kidnapping, isolationists, asserted, larger,
# Nearest to would: instead, reject, they, determination, if, else, compendium, setback,
# Nearest to if: would, dilemmas, spina, illumination, pheromone, bearings, toot, thin,
# Nearest to when: booking, mathematical, santer, harmful, interrupt, pacifist, reddy, insurers,
# Nearest to his: statesmen, kidnapped, ld, thema, encounter, spaniards, informants, bautista,
# Nearest to defense: hereditary, portraiture, hudson, nodes, entscheidungsproblem, eliminating, amended, camelopardalis,
# Nearest to institute: tur, reshaped, com, adjuncts, purity, spoofing, planing, whaler,
# Nearest to channel: on, commemorates, renamed, subsequent, caucasoid, sans, fujita, oasis,
# Nearest to mathematics: femme, ella, chair, doorway, joys, chemotherapy, richness, vita,
# Nearest to brother: colt, rig, ancillon, evelyn, ibero, tutelary, regents, wojty,
# Nearest to centre: habsburg, seabirds, bishop, kushan, almoravids, omnipotent, decarlo, archbishop,
# Nearest to running: prepubescent, incapable, shadows, greenish, bootlegs, rogue, extensive, attacking,
# Nearest to universe: tempe, theory, apprehend, takers, discovery, inheritance, travellers, bius,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4522 0.0224 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4257 0.0216 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4276 0.0219 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3909 0.0219 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3823 0.0219 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4532 0.0216 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.4013 0.0217 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.4015 0.0216 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3904 0.0217 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3466 0.0216 sec/batch
# Nearest to d: composer, jacinto, capell, mumford, vandalised, yue, collegetown, artist,
# Nearest to while: instantiated, sharp, hydrothermal, exposure, wastage, deploy, destroys, huns,
# Nearest to that: so, character, agnostic, evidence, reciprocal, order, hempstead, wave,
# Nearest to and: viceroys, aboriginals, thigh, shred, isolationists, spooky, extinguish, kidnapping,
# Nearest to would: they, reject, instead, determination, else, akhenaten, prokaryote, if,
# Nearest to if: would, illumination, daylight, dilemmas, toot, bulky, spina, asymmetry,
# Nearest to when: booking, mathematical, interrupt, santer, harmful, company, undertakes, intercepted,
# Nearest to his: statesmen, kidnapped, encounter, mornay, thema, lacan, informants, westchester,
# Nearest to defense: hereditary, portraiture, nodes, figurehead, amended, hudson, entscheidungsproblem, courts,
# Nearest to institute: tur, com, reshaped, adjuncts, spoofing, purity, planing, essex,
# Nearest to channel: on, commemorates, renamed, subsequent, caucasoid, sans, sinuous, poznan,
# Nearest to mathematics: femme, existence, joys, ella, chair, fallacies, doorway, chemotherapy,
# Nearest to brother: rig, ancillon, colt, ibero, evelyn, regents, tutelary, wojty,
# Nearest to centre: habsburg, seabirds, almoravids, omnipotent, bishop, kushan, decarlo, landers,
# Nearest to running: shadows, prepubescent, incapable, bootlegs, attacking, greenish, rogue, bookchin,
# Nearest to universe: tempe, theory, apprehend, discovery, takers, inheritance, physicists, insecurity,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3815 0.0225 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3719 0.0218 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3817 0.0217 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3673 0.0216 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3932 0.0218 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3474 0.0220 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3736 0.0214 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3790 0.0218 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3021 0.0219 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3292 0.0216 sec/batch
# Nearest to d: composer, mumford, jacinto, capell, yue, egan, collegetown, une,
# Nearest to while: huns, destroys, instantiated, wastage, opioids, hydrothermal, broadleaf, exposure,
# Nearest to that: so, agnostic, reciprocal, evidence, character, order, scientifique, guatemala,
# Nearest to and: viceroys, aboriginals, quetzalcoatl, extinguish, thigh, shred, spooky, of,
# Nearest to would: they, reject, instead, determination, else, prokaryote, if, akhenaten,
# Nearest to if: would, illumination, dilemmas, daylight, toot, bulky, asymmetry, ligature,
# Nearest to when: booking, mathematical, santer, undertakes, interrupt, intercepted, headaches, harmful,
# Nearest to his: statesmen, kidnapped, spaniards, encounter, mornay, informants, thema, he,
# Nearest to defense: hereditary, portraiture, nodes, amended, figurehead, courts, hudson, unsuccessfully,
# Nearest to institute: tur, com, adjuncts, reshaped, spoofing, purity, planing, essex,
# Nearest to channel: on, commemorates, renamed, sinuous, poznan, subsequent, mini, mutinies,
# Nearest to mathematics: femme, joys, ella, existence, chair, fallacies, theorem, massa,
# Nearest to brother: regents, rig, colt, ancillon, walid, ibero, evelyn, laramie,
# Nearest to centre: habsburg, seabirds, almoravids, kushan, omnipotent, robeson, bishop, port,
# Nearest to running: shadows, bootlegs, hee, attacking, incapable, newest, bookchin, rogue,
# Nearest to universe: tempe, apprehend, theory, discovery, physicists, takers, destiny, magnolias,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3519 0.0224 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3022 0.0218 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3602 0.0215 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3747 0.0218 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3885 0.0226 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3020 0.0217 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3120 0.0218 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3426 0.0224 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2122 0.0235 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2958 0.0239 sec/batch
# Nearest to d: composer, mumford, capell, jacinto, councilor, yue, artist, statesman,
# Nearest to while: huns, instantiated, nansen, sharp, destroys, wastage, hydrothermal, anachronisms,
# Nearest to that: agnostic, so, reciprocal, evidence, justify, guatemala, mccarthyism, hempstead,
# Nearest to and: viceroys, aboriginals, extinguish, quetzalcoatl, shred, larger, isolationists, of,
# Nearest to would: they, instead, reject, prokaryote, else, determination, if, setback,
# Nearest to if: illumination, would, y, bulky, dilemmas, asymmetry, topological, choosing,
# Nearest to when: booking, santer, headaches, company, mathematical, undertakes, intercepted, interrupt,
# Nearest to his: statesmen, kidnapped, mornay, spaniards, encounter, thema, westchester, synge,
# Nearest to defense: portraiture, hereditary, amended, nodes, figurehead, courts, unsuccessfully, thanked,
# Nearest to institute: com, tur, adjuncts, reshaped, brin, spoofing, planing, pieced,
# Nearest to channel: on, commemorates, renamed, sinuous, poznan, caucasoid, oasis, subsequent,
# Nearest to mathematics: femme, joys, fallacies, existence, theorem, rhetoric, chair, dietmar,
# Nearest to brother: regents, colt, ancillon, rig, ibero, evelyn, kern, tutelary,
# Nearest to centre: habsburg, seabirds, port, almoravids, southwest, landers, ajax, kushan,
# Nearest to running: bookchin, attacking, shadows, bootlegs, hee, newest, rogue, confluence,
# Nearest to universe: tempe, discovery, theory, apprehend, physicists, takers, magnolias, destiny,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3176 0.0247 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3027 0.0232 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3336 0.0107 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2760 0.0242 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2237 0.0241 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2255 0.0219 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2403 0.0221 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2413 0.0227 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2004 0.0275 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1574 0.0287 sec/batch
# Nearest to d: composer, mumford, yue, egan, jacinto, councilor, capell, une,
# Nearest to while: huns, sharp, nansen, controlling, wastage, broadleaf, destroys, incense,
# Nearest to that: agnostic, so, guatemala, articulations, mccarthyism, reciprocal, scientifique, evidence,
# Nearest to and: viceroys, aboriginals, extinguish, kuk, of, larger, thigh, felling,
# Nearest to would: instead, they, prokaryote, setback, reject, else, if, sooner,
# Nearest to if: would, illumination, daylight, bulky, subtraction, objection, dilemmas, toot,
# Nearest to when: booking, santer, headaches, him, intercepted, reddy, scientifique, undertakes,
# Nearest to his: statesmen, mornay, kidnapped, spaniards, grocer, thema, reigned, he,
# Nearest to defense: portraiture, nodes, amended, hereditary, combat, thanked, courts, figurehead,
# Nearest to institute: com, adjuncts, tur, reshaped, brin, spoofing, trusteeship, fertilizers,
# Nearest to channel: on, renamed, commemorates, poznan, sinuous, mini, subsequent, oasis,
# Nearest to mathematics: femme, joys, fallacies, rhetoric, existence, chair, theorem, dietmar,
# Nearest to brother: regents, ancillon, rig, colt, walid, ibero, evelyn, kern,
# Nearest to centre: habsburg, seabirds, port, almoravids, southwest, kushan, landers, robeson,
# Nearest to running: bookchin, attacking, hee, shadows, bootlegs, newest, rogue, skid,
# Nearest to universe: tempe, theory, apprehend, discovery, physicists, takers, magnolias, destiny,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2355 0.0254 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2502 0.0233 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2461 0.0224 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1496 0.0226 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.2066 0.0218 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1576 0.0217 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1730 0.0217 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1724 0.0219 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1801 0.0227 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1995 0.0215 sec/batch
# Nearest to d: mumford, composer, yue, subgroup, egan, capell, une, collegetown,
# Nearest to while: sharp, exposure, hydrothermal, controlling, instantiated, incense, nansen, opioids,
# Nearest to that: agnostic, so, mccarthyism, evidence, articulations, reciprocal, justify, hempstead,
# Nearest to and: extinguish, of, aboriginals, larger, thigh, viceroys, shred, spooky,
# Nearest to would: instead, they, if, else, prokaryote, reject, determination, hurdle,
# Nearest to if: would, subtraction, bulky, daylight, reals, subsets, let, y,
# Nearest to when: booking, undertakes, mathematical, santer, interrupt, headaches, to, intercepted,
# Nearest to his: statesmen, kidnapped, mornay, grocer, spaniards, he, westchester, encounter,
# Nearest to defense: portraiture, nodes, amended, courts, combat, unsuccessfully, hereditary, thanked,
# Nearest to institute: com, adjuncts, tur, brin, org, reshaped, reviewed, millionth,
# Nearest to channel: on, renamed, commemorates, mini, sinuous, fujita, poznan, oasis,
# Nearest to mathematics: femme, joys, chair, theorem, fallacies, normed, rhetoric, proofs,
# Nearest to brother: colt, regents, ancillon, rig, walid, kern, helmet, subsequently,
# Nearest to centre: seabirds, habsburg, port, almoravids, robeson, prehistoric, hedy, bishop,
# Nearest to running: bookchin, attacking, hee, shadows, newest, skid, rogue, incapable,
# Nearest to universe: discovery, physicists, apprehend, theory, tempe, travellers, takers, hermetical,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1855 0.0221 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1931 0.0215 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1785 0.0220 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1527 0.0218 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2056 0.0229 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1826 0.0221 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2257 0.0219 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1601 0.0216 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1421 0.0215 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1816 0.0219 sec/batch
# Nearest to d: composer, mumford, capell, egan, une, yue, subgroup, jacinto,
# Nearest to while: hydrothermal, sharp, drifting, apollinaris, wastage, nansen, anachronisms, fades,
# Nearest to that: agnostic, so, mccarthyism, guatemala, some, evidence, hempstead, articulations,
# Nearest to and: of, extinguish, viceroys, felling, larger, aboriginals, istat, spooky,
# Nearest to would: if, they, instead, prokaryote, reject, else, prudent, hurdle,
# Nearest to if: would, daylight, reals, let, every, objection, t, transylvanian,
# Nearest to when: mathematical, santer, him, booking, undertakes, to, headaches, flips,
# Nearest to his: statesmen, mornay, he, encounter, grocer, kidnapped, mourning, informants,
# Nearest to defense: nodes, amended, portraiture, courts, unsuccessfully, eliminating, nlds, dail,
# Nearest to institute: com, adjuncts, tur, brin, org, reviewed, medical, spoofing,
# Nearest to channel: renamed, on, commemorates, sinuous, mini, shorebirds, poznan, coupe,
# Nearest to mathematics: femme, joys, proofs, fallacies, normed, rhetoric, theorem, chair,
# Nearest to brother: regents, colt, rig, ancillon, walid, tutelary, deborah, laramie,
# Nearest to centre: habsburg, seabirds, port, almoravids, bishop, hedy, robeson, archbishop,
# Nearest to running: bookchin, attacking, hee, shadows, skid, rogue, newest, bootlegs,
# Nearest to universe: discovery, tempe, apprehend, physicists, theory, travellers, hermetical, magnolias,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2117 0.0223 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1737 0.0218 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.2097 0.0218 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1810 0.0217 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1307 0.0221 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1509 0.0217 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1752 0.0216 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1188 0.0217 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1618 0.0217 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2040 0.0224 sec/batch
# Nearest to d: composer, councilor, mumford, capell, statesman, jacinto, artist, egan,
# Nearest to while: boomed, nansen, anachronisms, apollinaris, wingtip, waddington, drifting, wastage,
# Nearest to that: agnostic, so, mccarthyism, guatemala, articulations, bangs, some, evidence,
# Nearest to and: of, viceroys, campaigner, extinguish, beaumont, istat, thigh, spooky,
# Nearest to would: they, if, instead, reject, prudent, setback, sooner, pretext,
# Nearest to if: would, daylight, let, cripple, apply, objection, toot, reals,
# Nearest to when: to, santer, him, mathematical, undertakes, intercepted, headaches, booking,
# Nearest to his: statesmen, he, mornay, grocer, kidnapped, mourning, antwerp, activism,
# Nearest to defense: portraiture, nodes, unsuccessfully, amended, courts, thanked, dail, igbo,
# Nearest to institute: com, adjuncts, tur, brin, medical, org, reviewed, spoofing,
# Nearest to channel: renamed, on, sinuous, shorebirds, poznan, commemorates, mini, backwaters,
# Nearest to mathematics: femme, joys, chair, proofs, fallacies, massa, rhetoric, existence,
# Nearest to brother: regents, colt, ancillon, rig, younger, walid, subsequently, counsellor,
# Nearest to centre: habsburg, port, seabirds, almoravids, bishop, archbishop, hedy, robeson,
# Nearest to running: bookchin, attacking, hee, skid, shadows, incapable, rogue, batgirl,
# Nearest to universe: tempe, discovery, apprehend, theory, physicists, omniscient, destiny, magnolias,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2001 0.0224 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1584 0.0217 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1469 0.0220 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1406 0.0219 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0621 0.0219 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1439 0.0216 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1536 0.0220 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1250 0.0215 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1830 0.0050 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1025 0.0216 sec/batch
# Nearest to d: composer, mumford, councilor, capell, une, egan, jacinto, artist,
# Nearest to while: boomed, anachronisms, nansen, sharp, taberner, apollinaris, wingtip, drifting,
# Nearest to that: agnostic, articulations, so, mccarthyism, guatemala, bangs, to, some,
# Nearest to and: of, extinguish, larger, viceroys, by, salinity, felling, as,
# Nearest to would: if, instead, they, sooner, hurdle, setback, prudent, reject,
# Nearest to if: would, mathcal, let, daylight, t, cripple, subsets, toot,
# Nearest to when: to, santer, him, undertakes, headaches, booking, mathematical, flips,
# Nearest to his: he, statesmen, mornay, grocer, mourning, him, kidnapped, spaniards,
# Nearest to defense: nodes, portraiture, unsuccessfully, igbo, amended, illustrious, combat, thanked,
# Nearest to institute: com, adjuncts, brin, medical, tur, org, spoofing, reviewed,
# Nearest to channel: on, renamed, sinuous, mini, shorebirds, poznan, commemorates, coupe,
# Nearest to mathematics: femme, joys, proofs, fallacies, rhetoric, normed, richness, existence,
# Nearest to brother: regents, colt, ancillon, rig, freshman, younger, dost, subsequently,
# Nearest to centre: port, seabirds, habsburg, almoravids, archbishop, hedy, ajax, bishop,
# Nearest to running: bookchin, attacking, hee, skid, shadows, incapable, batgirl, rogue,
# Nearest to universe: discovery, tempe, apprehend, hermetical, comics, destiny, omniscient, physicists,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0543 0.0230 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0493 0.0218 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0921 0.0216 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0675 0.0217 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0968 0.0218 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0294 0.0216 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0934 0.0217 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0799 0.0215 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1451 0.0216 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0251 0.0218 sec/batch
# Nearest to d: mumford, composer, councilor, egan, capell, une, jacinto, yue,
# Nearest to while: boomed, anachronisms, nansen, sharp, intruders, wingtip, drifting, apollinaris,
# Nearest to that: agnostic, so, articulations, to, evidence, some, cetera, mccarthyism,
# Nearest to and: of, extinguish, larger, as, viceroys, spooky, by, thrace,
# Nearest to would: if, they, instead, sooner, else, hurdle, prudent, reject,
# Nearest to if: would, daylight, mathcal, toot, t, let, workplaces, objection,
# Nearest to when: to, headaches, santer, him, booking, undertakes, flips, mathematical,
# Nearest to his: he, statesmen, grocer, vending, mornay, koenigsegg, mourning, rickover,
# Nearest to defense: nodes, portraiture, unsuccessfully, igbo, amended, dail, organisers, nlds,
# Nearest to institute: com, adjuncts, org, brin, medical, reviewed, digest, spoofing,
# Nearest to channel: renamed, on, mini, sinuous, shorebirds, poznan, coupe, commemorates,
# Nearest to mathematics: femme, joys, proofs, fallacies, stafford, normed, rhetoric, dietmar,
# Nearest to brother: regents, colt, rig, ancillon, younger, freshman, subsequently, septimania,
# Nearest to centre: port, seabirds, habsburg, almoravids, archbishop, meadows, pawtucket, robeson,
# Nearest to running: bookchin, shadows, attacking, hee, rogue, skid, batgirl, incapable,
# Nearest to universe: discovery, apprehend, tempe, physicists, cosmological, theory, hermetical, omniscient,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0060 0.0226 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0626 0.0215 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0128 0.0215 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0481 0.0217 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0616 0.0214 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0548 0.0220 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0823 0.0219 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1057 0.0220 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0356 0.0217 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0549 0.0215 sec/batch
# Nearest to d: mumford, une, subgroup, composer, egan, capell, artist, councilor,
# Nearest to while: boomed, anachronisms, hydrothermal, nansen, intruders, drifting, apollinaris, sharp,
# Nearest to that: to, so, agnostic, some, articulations, cetera, this, eigenstate,
# Nearest to and: of, extinguish, as, by, which, spooky, the, larger,
# Nearest to would: they, if, reject, absentee, prudent, instead, hurdle, else,
# Nearest to if: would, mathcal, daylight, let, t, then, sqrtn, every,
# Nearest to when: to, santer, headaches, him, flips, undertakes, mathematical, happen,
# Nearest to his: he, statesmen, mornay, him, mourning, grocer, koenigsegg, rickover,
# Nearest to defense: portraiture, nodes, amended, unsuccessfully, igbo, illustrious, dail, nlds,
# Nearest to institute: adjuncts, com, medical, reviewed, research, sciences, tur, spoofing,
# Nearest to channel: renamed, on, mini, sinuous, shorebirds, coupe, maccabean, kwajalein,
# Nearest to mathematics: proofs, fallacies, joys, normed, femme, theorem, kummer, mathematicians,
# Nearest to brother: regents, colt, younger, dost, rig, ancillon, kel, nullified,
# Nearest to centre: port, habsburg, seabirds, archbishop, almoravids, robeson, pawtucket, hedy,
# Nearest to running: bookchin, shadows, hee, batgirl, attacking, rogue, skid, incapable,
# Nearest to universe: apprehend, discovery, tempe, cosmological, omniscient, destiny, sinai, theory,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0578 0.0226 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0541 0.0222 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0745 0.0218 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0593 0.0215 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0601 0.0217 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0597 0.0217 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0661 0.0218 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0628 0.0217 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0753 0.0216 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0662 0.0217 sec/batch
# Nearest to d: subgroup, mumford, capell, une, artist, bornemisza, egan, composer,
# Nearest to while: boomed, intruders, drifting, apollinaris, nansen, anachronisms, taberner, sharp,
# Nearest to that: to, so, guatemala, agnostic, some, articulations, eigenstate, bangs,
# Nearest to and: of, by, which, the, as, viceroys, extinguish, spooky,
# Nearest to would: if, they, pretext, prudent, setback, sooner, absentee, reject,
# Nearest to if: would, mathcal, let, daylight, toot, t, you, negativity,
# Nearest to when: to, santer, headaches, him, flips, undertakes, mais, mathematical,
# Nearest to his: he, statesmen, mornay, him, grocer, theophilus, sardis, mourning,
# Nearest to defense: portraiture, igbo, unsuccessfully, nodes, amended, dail, illustrious, competence,
# Nearest to institute: adjuncts, com, medical, faculty, reviewed, research, org, spoofing,
# Nearest to channel: renamed, on, mini, shorebirds, sinuous, coupe, kwajalein, broadcast,
# Nearest to mathematics: joys, femme, proofs, stafford, fallacies, richness, selected, dietmar,
# Nearest to brother: regents, colt, younger, dost, nullified, septimania, kel, rig,
# Nearest to centre: port, habsburg, archbishop, seabirds, almoravids, robeson, hedy, pawtucket,
# Nearest to running: bookchin, incapable, hee, attacking, rogue, skid, shadows, batgirl,
# Nearest to universe: apprehend, tempe, cosmological, discovery, sinai, destiny, omniscient, hermetical,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0698 0.0224 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9924 0.0216 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0531 0.0215 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0960 0.0215 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0744 0.0218 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1351 0.0220 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1281 0.0214 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0818 0.0218 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0222 0.0216 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0550 0.0215 sec/batch
# Nearest to d: capell, une, councilor, composer, mumford, subgroup, egan, montmorency,
# Nearest to while: boomed, drifting, taberner, apollinaris, intruders, anachronisms, magdeburg, ocogs,
# Nearest to that: to, eigenstate, articulations, so, agnostic, guatemala, some, eventually,
# Nearest to and: of, extinguish, as, by, the, which, spooky, viceroys,
# Nearest to would: they, pretext, if, setback, sooner, reject, prudent, instead,
# Nearest to if: mathcal, let, would, y, then, t, sqrtn, daylight,
# Nearest to when: to, flips, santer, headaches, him, mais, mathematical, undertakes,
# Nearest to his: he, grocer, mornay, koenigsegg, grist, statesmen, invites, him,
# Nearest to defense: igbo, portraiture, illustrious, unsuccessfully, nodes, amended, competence, provisionally,
# Nearest to institute: adjuncts, faculty, com, research, spoofing, medical, reviewed, org,
# Nearest to channel: renamed, on, sinuous, shorebirds, mini, kwajalein, backwaters, coupe,
# Nearest to mathematics: proofs, joys, femme, fallacies, stafford, kummer, richness, massa,
# Nearest to brother: regents, colt, younger, nullified, ancillon, dost, subsequently, kel,
# Nearest to centre: port, habsburg, archbishop, seabirds, almoravids, robeson, hedy, pawtucket,
# Nearest to running: bookchin, incapable, rogue, hee, batgirl, attacking, skid, shadows,
# Nearest to universe: tempe, apprehend, destiny, discovery, sinai, omniscient, cosmological, magnolias,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9546 0.0222 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0207 0.0217 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0206 0.0217 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0572 0.0218 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0546 0.0220 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0238 0.0214 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0013 0.0215 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9822 0.0215 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0386 0.0218 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9607 0.0218 sec/batch
# Nearest to d: capell, egan, composer, mumford, councilor, artist, une, subgroup,
# Nearest to while: boomed, apollinaris, intruders, anachronisms, drifting, taberner, nansen, casualty,
# Nearest to that: to, so, articulations, agnostic, this, eigenstate, some, guatemala,
# Nearest to and: of, as, extinguish, by, the, which, spooky, viceroys,
# Nearest to would: they, if, sooner, pretext, instead, setback, else, to,
# Nearest to if: daylight, would, let, mathcal, t, negativity, you, airdrop,
# Nearest to when: to, santer, headaches, him, flips, mathematical, undertakes, mais,
# Nearest to his: he, statesmen, him, grocer, grist, revolts, mornay, gepids,
# Nearest to defense: igbo, portraiture, offense, illustrious, nodes, unsuccessfully, defence, composite,
# Nearest to institute: faculty, adjuncts, research, com, canberra, org, engineering, medical,
# Nearest to channel: on, renamed, shorebirds, mini, sinuous, kwajalein, coupe, broadcast,
# Nearest to mathematics: proofs, joys, stafford, kummer, fallacies, richness, femme, theorem,
# Nearest to brother: regents, younger, colt, nullified, septimania, subsequently, kel, dost,
# Nearest to centre: port, habsburg, almoravids, archbishop, seabirds, mall, robeson, pawtucket,
# Nearest to running: bookchin, rogue, hee, incapable, skid, attacking, shadows, batgirl,
# Nearest to universe: apprehend, tempe, omniscient, destiny, comics, magnolias, hermetical, sinai,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9876 0.0224 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9407 0.0218 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0347 0.0218 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0209 0.0217 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0164 0.0214 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0111 0.0216 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9200 0.0219 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9754 0.0218 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9052 0.0214 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9697 0.0219 sec/batch
# Nearest to d: subgroup, mumford, capell, une, egan, heer, composer, ambrosians,
# Nearest to while: boomed, intruders, drifting, sharp, hydrothermal, correlated, venezuelan, partnerships,
# Nearest to that: to, this, so, agnostic, articulations, eigenstate, justify, eventually,
# Nearest to and: of, as, the, which, by, extinguish, in, spooky,
# Nearest to would: if, they, else, pretext, to, however, instead, grohl,
# Nearest to if: would, mathcal, daylight, let, t, you, every, then,
# Nearest to when: to, santer, flips, headaches, him, once, mathematical, happen,
# Nearest to his: he, him, forehand, revolts, mornay, grocer, koenigsegg, grist,
# Nearest to defense: offense, igbo, illustrious, portraiture, nodes, defence, nlds, linebackers,
# Nearest to institute: faculty, adjuncts, engineering, sciences, canberra, research, medical, wharton,
# Nearest to channel: on, renamed, shorebirds, sinuous, kwajalein, coupe, broadcast, mini,
# Nearest to mathematics: proofs, kummer, fallacies, joys, stafford, richness, dietmar, mathematicians,
# Nearest to brother: regents, colt, younger, nullified, kel, dost, septimania, deborah,
# Nearest to centre: port, habsburg, archbishop, almoravids, seabirds, mall, robeson, pawtucket,
# Nearest to running: rogue, skid, bookchin, incapable, batgirl, hee, attacking, shadows,
# Nearest to universe: apprehend, tempe, omniscient, sinai, hermetical, cosmological, magnolias, discovery,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9958 0.0222 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9834 0.0217 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9603 0.0217 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9965 0.0217 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0103 0.0218 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9797 0.0217 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9961 0.0218 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0013 0.0215 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9953 0.0216 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0000 0.0217 sec/batch
# Nearest to d: capell, artist, composer, subgroup, mumford, egan, heer, councilor,
# Nearest to while: boomed, drifting, apollinaris, partnerships, intruders, sharp, taberner, anachronisms,
# Nearest to that: to, this, eigenstate, agnostic, justify, so, not, some,
# Nearest to and: of, as, the, which, by, in, spooky, subexpression,
# Nearest to would: they, to, pretext, if, however, reject, else, prudent,
# Nearest to if: mathcal, would, daylight, let, then, t, you, every,
# Nearest to when: to, santer, flips, him, headaches, booking, mais, happen,
# Nearest to his: he, mornay, him, koenigsegg, aphorisms, revolts, had, grist,
# Nearest to defense: offense, igbo, illustrious, portraiture, defence, competence, nodes, nlds,
# Nearest to institute: adjuncts, research, engineering, canberra, faculty, sciences, com, org,
# Nearest to channel: on, renamed, shorebirds, sinuous, mini, kwajalein, thunderball, broadcast,
# Nearest to mathematics: kummer, joys, proofs, richness, fallacies, selected, dietmar, theorem,
# Nearest to brother: regents, younger, colt, nullified, septimania, dost, walid, laramie,
# Nearest to centre: port, archbishop, habsburg, almoravids, robeson, seabirds, mall, pawtucket,
# Nearest to running: rogue, bookchin, skid, incapable, batgirl, shadows, attacking, hee,
# Nearest to universe: apprehend, tempe, hermetical, sinai, discovery, omniscient, cosmological, magnolias,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9978 0.0226 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9773 0.0216 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9986 0.0219 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9997 0.0219 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0128 0.0218 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0060 0.0217 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9866 0.0219 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9518 0.0218 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9799 0.0215 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0061 0.0217 sec/batch
# Nearest to d: capell, artist, subgroup, composer, mumford, montmorency, egan, jacinto,
# Nearest to while: boomed, included, drifting, apollinaris, intruders, partnerships, taberner, ocogs,
# Nearest to that: to, this, justify, so, eventually, eigenstate, some, agnostic,
# Nearest to and: of, the, as, by, in, which, s, viceroys,
# Nearest to would: they, to, however, pretext, if, reject, else, setback,
# Nearest to if: let, mathcal, would, daylight, you, t, then, airdrop,
# Nearest to when: to, santer, him, headaches, remitted, flips, booking, undertakes,
# Nearest to his: he, koenigsegg, mornay, him, seminar, aphorisms, grist, theophilus,
# Nearest to defense: igbo, defence, offense, illustrious, competence, portraiture, military, dail,
# Nearest to institute: adjuncts, research, canberra, faculty, engineering, spoofing, medical, com,
# Nearest to channel: on, renamed, shorebirds, sinuous, kwajalein, mini, thunderball, broadcast,
# Nearest to mathematics: kummer, proofs, richness, joys, stafford, massa, euclid, fallacies,
# Nearest to brother: younger, regents, colt, septimania, nullified, dost, counsellor, kel,
# Nearest to centre: archbishop, port, almoravids, habsburg, robeson, seabirds, mall, woodside,
# Nearest to running: skid, rogue, incapable, bookchin, batgirl, fd, seize, hee,
# Nearest to universe: apprehend, omniscient, sinai, tempe, hermetical, destiny, magnolias, cosmological,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9320 0.0225 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.1021 0.0218 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0245 0.0223 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0369 0.0215 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9516 0.0216 sec/batch
# ...
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8646 0.0218 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8355 0.0216 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8629 0.0217 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8832 0.0218 sec/batch
# Nearest to d: subgroup, artist, francophones, jacinto, mouhoun, composer, offspring, biographie,
# Nearest to while: included, drifting, apollinaris, boomed, and, venezuelan, also, in,
# Nearest to that: to, this, not, it, and, in, but, be,
# Nearest to and: of, the, as, in, for, which, by, to,
# Nearest to would: however, to, if, they, that, pretext, selvin, naps,
# Nearest to if: would, mathcal, then, t, seriously, pointwise, way, you,
# Nearest to when: to, once, and, this, that, of, mastered, him,
# Nearest to his: he, him, forehand, fostered, had, seminar, veishea, fruity,
# Nearest to defense: offense, defence, linebackers, interception, military, dworkin, blindly, defending,
# Nearest to institute: research, institutes, therapy, polytechnic, sprague, college, adjuncts, classmate,
# Nearest to channel: itv, mini, shorebirds, thunderball, renamed, on, univision, cbc,
# Nearest to mathematics: kummer, joys, cores, richness, chemotherapy, ecd, euclid, maximising,
# Nearest to brother: younger, regents, colt, according, septimania, mimicking, niddah, rig,
# Nearest to centre: archbishop, centres, citadel, liberal, glasgow, statue, odp, port,
# Nearest to running: plains, as, rt, employees, batgirl, seize, incapable, offensive,
# Nearest to universe: omniscient, theory, cosmological, comics, tsr, redshift, magnolias, apprehend,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8518 0.0225 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8693 0.0217 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8404 0.0219 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8629 0.0218 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8597 0.0215 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8896 0.0218 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8622 0.0217 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8472 0.0216 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8631 0.0217 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8765 0.0215 sec/batch
# Nearest to d: subgroup, francophones, offspring, artist, mouhoun, inferior, jacinto, uneventful,
# Nearest to while: drifting, apollinaris, included, boomed, also, and, in, venezuelan,
# Nearest to that: this, to, it, not, in, but, and, of,
# Nearest to and: of, the, in, as, for, by, which, to,
# Nearest to would: to, however, if, pretext, that, they, exists, been,
# Nearest to if: would, mathcal, t, rudd, then, daylight, seriously, snider,
# Nearest to when: to, and, once, this, of, that, him, santer,
# Nearest to his: he, him, seminar, had, was, veishea, lecture, printing,
# Nearest to defense: offense, defence, military, interception, linebackers, dworkin, blindly, ministry,
# Nearest to institute: research, sprague, therapy, classmate, institutes, spoofing, adjuncts, canberra,
# Nearest to channel: itv, thunderball, mini, shorebirds, renamed, cbc, on, univision,
# Nearest to mathematics: kummer, richness, cores, euclid, joys, ecd, chemotherapy, maximising,
# Nearest to brother: younger, regents, colt, according, septimania, counsellor, niddah, rig,
# Nearest to centre: archbishop, liberal, centres, citadel, glasgow, minster, odp, robeson,
# Nearest to running: seize, hee, plains, employees, incapable, rt, skid, as,
# Nearest to universe: omniscient, cosmological, comics, theory, apprehend, redshift, garret, tsr,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8707 0.0223 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8103 0.0217 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8349 0.0219 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8464 0.0220 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8814 0.0218 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8269 0.0215 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9653 0.0216 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8827 0.0217 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8727 0.0217 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8373 0.0217 sec/batch
# Nearest to d: subgroup, artist, jacinto, offspring, mouhoun, francophones, composer, biographie,
# Nearest to while: included, drifting, in, apollinaris, boomed, and, ocogs, also,
# Nearest to that: to, this, it, in, not, and, of, but,
# Nearest to and: of, the, in, as, for, s, to, which,
# Nearest to would: to, if, however, pretext, that, they, sooner, exists,
# Nearest to if: would, mathcal, rudd, that, negativity, you, t, furthermore,
# Nearest to when: to, once, and, this, that, him, of, remitted,
# Nearest to his: he, him, had, seminar, was, lecture, after, veishea,
# Nearest to defense: defence, offense, military, interception, ministry, linebackers, dworkin, igbo,
# Nearest to institute: research, sprague, institutes, physics, spoofing, classmate, therapy, adjuncts,
# Nearest to channel: itv, thunderball, shorebirds, mini, renamed, on, univision, eec,
# Nearest to mathematics: kummer, richness, joys, euclid, cores, ecd, chemotherapy, mississippi,
# Nearest to brother: younger, regents, colt, septimania, according, deborah, mimicking, niddah,
# Nearest to centre: archbishop, citadel, centres, glasgow, port, liberal, statue, bezirke,
# Nearest to running: seize, plains, employees, nicholas, tco, skid, rt, incapable,
# Nearest to universe: omniscient, comics, cosmological, apprehend, garret, tsr, redshift, theory,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8205 0.0223 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8578 0.0218 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8163 0.0216 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8628 0.0217 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8399 0.0221 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8437 0.0221 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8690 0.0147 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8603 0.0215 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7957 0.0217 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8576 0.0214 sec/batch
# Nearest to d: artist, jacinto, composer, biographie, mumford, mouhoun, councilor, one,
# Nearest to while: included, and, in, drifting, boomed, also, apollinaris, as,
# Nearest to that: this, to, it, but, not, for, in, and,
# Nearest to and: of, the, in, as, for, to, which, by,
# Nearest to would: to, however, if, that, pretext, instead, had, they,
# Nearest to if: would, mathcal, t, rudd, furthermore, that, negativity, you,
# Nearest to when: to, once, and, this, that, him, of, had,
# Nearest to his: he, him, had, was, himself, seminar, father, forehand,
# Nearest to defense: offense, defence, interception, military, linebackers, dworkin, igbo, ministry,
# Nearest to institute: research, therapy, institutes, classmate, sprague, adjuncts, school, spoofing,
# Nearest to channel: itv, thunderball, shorebirds, mini, renamed, cbc, rupert, negotiate,
# Nearest to mathematics: kummer, richness, joys, ecd, euclid, cores, chemotherapy, mississippi,
# Nearest to brother: younger, regents, colt, septimania, according, counsellor, niddah, abernethy,
# Nearest to centre: citadel, archbishop, centres, liberal, glasgow, odp, minster, bezirke,
# Nearest to running: plains, employees, seize, skid, as, tco, hee, fraggle,
# Nearest to universe: omniscient, comics, apprehend, cosmological, tsr, garret, magnolias, theory,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8116 0.0224 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8384 0.0221 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8035 0.0217 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8257 0.0218 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8456 0.0215 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8414 0.0215 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8951 0.0216 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7250 0.0215 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8032 0.0217 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7996 0.0218 sec/batch
# Nearest to d: subgroup, jacinto, mouhoun, offspring, artist, francophones, mumford, biographie,
# Nearest to while: and, also, in, included, boomed, drifting, venezuelan, apollinaris,
# Nearest to that: this, to, in, it, not, be, and, the,
# Nearest to and: of, in, the, as, for, which, by, to,
# Nearest to would: to, however, if, that, they, instead, pretext, so,
# Nearest to if: would, that, mathcal, you, t, then, y, pointwise,
# Nearest to when: to, once, this, and, that, remitted, him, had,
# Nearest to his: he, him, had, himself, forehand, was, seminar, lak,
# Nearest to defense: offense, defence, military, interception, linebackers, ministry, dworkin, igbo,
# Nearest to institute: research, therapy, institutes, classmate, institutions, school, sprague, adjuncts,
# Nearest to channel: itv, thunderball, shorebirds, on, cbc, renamed, mini, univision,
# Nearest to mathematics: kummer, euclid, joys, ecd, richness, chemotherapy, cores, comprehension,
# Nearest to brother: younger, colt, regents, according, niddah, loops, mimicking, deborah,
# Nearest to centre: citadel, archbishop, centres, liberal, glasgow, ludus, bezirke, odp,
# Nearest to running: plains, seize, skid, employees, fraggle, rogue, incapable, tco,
# Nearest to universe: cosmological, omniscient, comics, theory, apprehend, garret, tsr, redshift,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7728 0.0223 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8470 0.0216 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8637 0.0216 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7999 0.0216 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8270 0.0215 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8894 0.0220 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8360 0.0217 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8339 0.0217 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8081 0.0268 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8220 0.0269 sec/batch
# Nearest to d: subgroup, artist, offspring, francophones, jacinto, biographie, mouhoun, habitation,
# Nearest to while: boomed, also, included, drifting, and, venezuelan, in, apollinaris,
# Nearest to that: this, to, it, not, of, but, and, in,
# Nearest to and: of, in, the, as, for, by, to, a,
# Nearest to would: to, however, if, pretext, they, later, selvin, that,
# Nearest to if: would, mathcal, you, t, then, rudd, snider, bq,
# Nearest to when: to, once, this, and, of, him, remitted, in,
# Nearest to his: he, him, seminar, had, himself, aphorisms, was, odie,
# Nearest to defense: defence, offense, military, interception, ministry, linebackers, dworkin, defending,
# Nearest to institute: research, institutes, therapy, college, classmate, school, sprague, institutions,
# Nearest to channel: itv, thunderball, shorebirds, univision, cbc, mini, on, centronics,
# Nearest to mathematics: kummer, euclid, joys, richness, ecd, chemotherapy, comprehension, knot,
# Nearest to brother: younger, regents, colt, according, counsellor, septimania, niddah, mother,
# Nearest to centre: archbishop, centres, liberal, citadel, glasgow, ludus, robeson, minster,
# Nearest to running: plains, seize, employees, skid, fraggle, upgrading, the, offensive,
# Nearest to universe: cosmological, comics, omniscient, theory, garret, apprehend, tsr, redshift,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8723 0.0296 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8563 0.0272 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8329 0.0252 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8286 0.0218 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8635 0.0216 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8493 0.0233 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8511 0.0224 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8393 0.0222 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8477 0.0219 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8170 0.0223 sec/batch
# Nearest to d: francophones, subgroup, offspring, artist, jacinto, mouhoun, daimyo, inferior,
# Nearest to while: and, also, in, included, boomed, apollinaris, as, drifting,
# Nearest to that: this, to, it, of, in, not, but, for,
# Nearest to and: of, the, in, as, for, to, by, which,
# Nearest to would: to, however, if, they, pretext, that, exists, had,
# Nearest to if: would, you, t, rudd, mathcal, that, furthermore, y,
# Nearest to when: to, this, once, and, that, of, remitted, whitish,
# Nearest to his: he, him, had, obtained, forehand, seminar, was, himself,
# Nearest to defense: defence, offense, military, interception, ministry, linebackers, dworkin, azeglio,
# Nearest to institute: research, therapy, institutes, classmate, college, sprague, physics, school,
# Nearest to channel: itv, thunderball, on, mini, univision, centronics, shorebirds, cbc,
# Nearest to mathematics: kummer, euclid, joys, richness, chemotherapy, ecd, knot, cores,
# Nearest to brother: younger, regents, colt, according, septimania, mimicking, niddah, mother,
# Nearest to centre: archbishop, centres, liberal, citadel, glasgow, ludus, robeson, minster,
# Nearest to running: seize, skid, employees, tco, plains, incapable, the, higher,
# Nearest to universe: omniscient, comics, cosmological, apprehend, garret, tsr, concepts, theory,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8429 0.0224 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8085 0.0236 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8976 0.0224 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9179 0.0223 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8966 0.0220 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8002 0.0246 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7702 0.0275 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8302 0.0225 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7651 0.0238 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8318 0.0282 sec/batch
# Nearest to d: artist, biographie, composer, jacinto, livingston, councilor, francophones, offspring,
# Nearest to while: included, in, boomed, and, also, apollinaris, as, kosovo,
# Nearest to that: this, to, it, not, of, even, and, in,
# Nearest to and: of, in, the, as, for, to, by, which,
# Nearest to would: to, however, they, pretext, if, had, been, later,
# Nearest to if: t, then, would, you, mathcal, rudd, that, pointwise,
# Nearest to when: to, once, this, and, wanted, that, remitted, of,
# Nearest to his: he, him, had, himself, krestinsky, iskra, seminar, was,
# Nearest to defense: defence, offense, interception, military, dworkin, ministry, illustrious, linebackers,
# Nearest to institute: research, therapy, institutes, physics, classmate, school, college, pstn,
# Nearest to channel: itv, thunderball, shorebirds, mini, cbc, centronics, sous, on,
# Nearest to mathematics: kummer, joys, richness, ecd, euclid, chemotherapy, mississippi, westermann,
# Nearest to brother: younger, regents, colt, septimania, according, banker, mimicking, mother,
# Nearest to centre: archbishop, centres, citadel, liberal, glasgow, port, minster, odp,
# Nearest to running: tco, plains, employees, seize, skid, the, rt, statehouse,
# Nearest to universe: omniscient, comics, cosmological, apprehend, garret, tsr, theory, concepts,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8376 0.0305 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8139 0.0217 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
